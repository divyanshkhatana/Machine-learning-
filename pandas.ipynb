# %% [markdown]
# # pandas for ML

# %%
## data analysis toolkit
## fast and eficient datafram

# %%
  import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
series=pd.Series([1,2,3,4])

# %%
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series1=pd.Series([1,2,3,4],index=['a','b','c','d'],dtype=float)

# %%
print(series1)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
scalar_s=pd.Series(0.5)

# %%
print(scalar_s)
# Out:
# 0    0.5
# dtype: float64

# %%
scalar_s=pd.Series(0.5 ,index=[1,2,3])

# %%
print(scalar_s)
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
s4=pd.Series([1,2,3,4,5])

# %%
s4[0]
# Out:
# 1

# %%
s4[1]
# Out:
# 2

# %%
## we can use min max

# %%
s4[s4>3]
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
series1+s4
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64

# %%
s1=[1,2,3,33,4]

# %%
s1+s4
# Out:
# 0     2
# 1     4
# 2     6
# 3    37
# 4     9
# dtype: int64

# %% [markdown]
# # pandas data frame

# %%
import pandas as pd
e=pd.DataFrame()

# %%
print(e)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst=['a','b','c']

# %%
print(lst)
# Out:
# ['a', 'b', 'c']

# %%
df1=pd.DataFrame(lst)

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
lsl=[[1,2,3],[2,3,4],[3,4,5]]

# %%
df2=pd.DataFrame(lsl)

# %%
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  3  4
# 2  3  4  5

# %%
dict1={ 'ID':[11,22,33,44]}
dict1
# Out:
# {'ID': [11, 22, 33, 44]}

# %%
df3=pd.DataFrame(dict1)

# %%
df3
# Out:
#    ID
# 0  11
# 1  22
# 2  33
# 3  44

# %%
ls_dict=[{'a':1,'b':2},{'a':3,'b':4,'c':5}]

# %%
ls_dict
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4, 'c': 5}]

# %%
df4=pd.DataFrame(ls_dict)

# %%
df4
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\DIVYANSH\Desktop\Machine Learning

# %% [markdown]
# # how to write csv files in pandas

# %%
 df=pd.read_csv('location' ,nrows=1, usecols=[1,3,4],skiprows=1) #to select specific rows and col and skiprows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-e291708602fa> in <module>
# ----> 1 df=pd.read_csv('location' ,nrows=1, usecols=[1,3,4],skiprows=1) #to select specific rows and col and skiprows
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
 index_col=2 ## to change index   ,header=1,header =none (if we dont have any data)

# %%
prefix='col' always use header =none with prefic

# %%
names=['a','b','c,'....]

# %%
df.head() ## to show table 
df.head(1) ## return one row
dp.tail() ##return rows from bottom deafult 5
dp.tail(2) ##return 2 rows from bottom

# %%
##dtype in read_csv for changing data type

# %%
##changing unnecessary string to any true or flase
## we use true_values=['YES'] in read_csv

# %% [markdown]
# # handling missing values

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
## Nan == not a number

# %%
na_filter='false'

# %%
df1.isnull().sum().sum()

# %%
df1.notnull()

# %%
## we can use isnull and not null in series also

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
df1

# %%
df1.dropna()

# %%
##fillna() -fill nan with given values
##syntax-- Dataframe.fillna()

# %%
import pandas as pd

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
df1

# %%
df1.fillna(2)

# %%
df1.fillna({'Industry_aggregation_NZSIOC':'Level1'})

# %%
df1.fillna(5,inplace=True)

# %%
df1

# %%
##replace function

# %%
df1.replace()
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %% [markdown]
# # interpolate()

# %%
##interpolte():is used to fill nan values  fill only numerical values

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1.interpolate()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1.interpolate()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# # pandas loc and iloc functions

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
df1.loc[0]
# Out:
# Year                                                                        2019
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H01
# Variable_name                                                       Total income
# Variable_category                                          Financial performance
# Value                                                                   7,28,239
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#       Value                             Industry_code_ANZSIC06
# 0  7,28,239  ANZSIC06 divisions A-S (excluding classes K633...
# 1  6,43,809  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df1.loc[0:2,'Year']
# Out:
# 0    2019
# 1    2019
# 2    2019
# Name: Year, dtype: int64

# %%
df1.loc[[False]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-6e42d4888eee> in <module>
# ----> 1 df1.loc[[False]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1912             return self._get_slice_axis(key, axis=axis)
#    1913         elif com.is_bool_indexer(key):
# -> 1914             return self._getbool_axis(key, axis=axis)
#    1915         elif is_list_like_indexer(key):
#    1916
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
# ...

# %%
df1.iloc[[0]]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
#
#                 Units Variable_code Variable_name      Variable_category  \
# 0  Dollars (millions)           H01  Total income  Financial performance
#
#       Value                             Industry_code_ANZSIC06
# 0  7,28,239  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df1.iloc[:1]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
#
#                 Units Variable_code Variable_name      Variable_category  \
# 0  Dollars (millions)           H01  Total income  Financial performance
#
#       Value                             Industry_code_ANZSIC06
# 0  7,28,239  ANZSIC06 divisions A-S (excluding classes K633...

# %% [markdown]
# # group by function
# ### -splitting the object
# ### -applying a function
# ### -combining the result

# %%
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1.groupby(by='Industry_aggregation_NZSIOC').groups
# Out:
# {'Level 1': Int64Index([    0,     1,     4,     5,     6,     7,     8,     9,    10,
#                 11,
#              ...
#              32143, 32144, 32145, 32146, 32147, 32148, 32149, 32150, 32151,
#              32152],
#             dtype='int64', length=3911),
#  'Level 3': Int64Index([   62,    63,    64,    65,    66,    67,    68,    69,    70,
#                 71,
#              ...
#              32435, 32436, 32437, 32438, 32439, 32440, 32441, 32442, 32443,
#              32444],
#             dtype='int64', length=10773),
#  'Level 4': Int64Index([   92,    93,    94,    95,    96,    97,    98,    99,   100,
#                101,
#              ...
#              32399, 32400, 32401, 32402, 32403, 32404, 32405, 32406, 32407,
#              32408],
#             dtype='int64', length=17759)}

# %%
gr3=df1.groupby('Year').get_group(2019)

# %%
gr3
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2019                     Level 1                99999
# 1     2019                     Level 1                99999
# 2     2019                         NaN                99999
# 3     2019                         NaN                99999
# 4     2019                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2019                     Level 3                 ZZ11
# 4631  2019                     Level 3                 ZZ11
# 4632  2019                     Level 3                 ZZ11
# 4633  2019                     Level 3                 ZZ11
# 4634  2019                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# ...

# %%
gr3.describe()
# Out:
#          Year
# count  4635.0
# mean   2019.0
# std       0.0
# min    2019.0
# 25%    2019.0
# 50%    2019.0
# 75%    2019.0
# max    2019.0

# %% [markdown]
# # merge function

# %%
##merge function --connects col or ind in df based on one or more keys

# %%
df1=pd.DataFrame({'id':[1,2,3,4],'name':['a','v','c','d']})
df1
# Out:
#    id name
# 0   1    a
# 1   2    v
# 2   3    c
# 3   4    d

# %%
df2=pd.DataFrame({'id':[1,2,3,4],'class':['2','3','4','5']})

# %%
pd.merge(df1,df2,on='id')
# Out:
#    id name class
# 0   1    a     2
# 1   2    v     3
# 2   3    c     4
# 3   4    d     5

# %%
  ##concate()

# %%
s1=pd.Series([1,2,3])

# %%
s2=pd.Series([4,5,6])

# %%
pd.concat([s2,s1])
# Out:
# 0    4
# 1    5
# 2    6
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# # pandas join

# %%
import pandas as pd

# %%
df2=pd.DataFrame({'id':[1,2,3,4],'class':[1,2,3,4]})
df1=pd.DataFrame({'i':[5,6,7,8],'clas':[5,6,7,8]})

# %%
display(df1,df2)
# Out:
#    i  clas
# 0  5     5
# 1  6     6
# 2  7     7
# 3  8     8
#    id  class
# 0   1      1
# 1   2      2
# 2   3      3
# 3   4      4

# %%
df1.join(df2)
# Out:
#    i  clas  id  class
# 0  5     5   1      1
# 1  6     6   2      2
# 2  7     7   3      3
# 3  8     8   4      4

# %%
df2.join(df1)
# Out:
#    id  class  i  clas
# 0   1      1  5     5
# 1   2      2  6     6
# 2   3      3  7     7
# 3   4      4  8     8

# %% [markdown]
# # pandas append

# %%
df1=pd.DataFrame({'id':[1,2,3,4],'class':[1,2,3,4]})

# %%
df2=pd.DataFrame({'id':[5,6],'class':[5,6]})

# %%
df1.append(df2)
# Out:
#    id  class
# 0   1      1
# 1   2      2
# 2   3      3
# 3   4      4
# 0   5      5
# 1   6      6

# %% [markdown]
# # pivot table

# %%
df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                         NaN                99999
# 3      2019                         NaN                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1.pivot_table(index='Industry_aggregation_NZSIOC')
# Out:
#                                     Year
# Industry_aggregation_NZSIOC
# Level 1                      2015.998466
# Level 3                      2016.000000
# Level 4                      2016.000000

# %% [markdown]
# # pandas melt:- used to transform or reshape data

# %%
 df1=pd.read_csv("C:\\Users\\DIVYANSH\\Desktop\\Machine Learning\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")

# %%
pd.melt(df1)
# Out:
#                       variable  \
# 0                         Year
# 1                         Year
# 2                         Year
# 3                         Year
# 4                         Year
# ...                        ...
# 324445  Industry_code_ANZSIC06
# 324446  Industry_code_ANZSIC06
# 324447  Industry_code_ANZSIC06
# 324448  Industry_code_ANZSIC06
# 324449  Industry_code_ANZSIC06
#
#                                                     value
# 0                                                    2019
# 1                                                    2019
# 2                                                    2019
# 3                                                    2019
# 4                                                    2019
# ...                                                   ...
# 324445  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 324446  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# ...
